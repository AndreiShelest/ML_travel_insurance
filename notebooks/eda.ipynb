# %%
# %load_ext kedro.ipython
# Out:
# [01/06/25 15:10:25] INFO     Using                                                                  ]8;id=927573;file://c:\Users\shele\miniforge3\envs\ML_II\Lib\site-packages\kedro\framework\project\__init__.py\__init__.py]8;;\:]8;id=106079;file://c:\Users\shele\miniforge3\envs\ML_II\Lib\site-packages\kedro\framework\project\__init__.py#270\270]8;;\
#                              'c:\Users\shele\miniforge3\envs\ML_II\Lib\site-packages\kedro\framewor
#                              k\project\rich_logging.yml' as logging configuration.
#                     INFO     Registered line magic '%reload_kedro'                                   ]8;id=115219;file://c:\Users\shele\miniforge3\envs\ML_II\Lib\site-packages\kedro\ipython\__init__.py\__init__.py]8;;\:]8;id=809126;file://c:\Users\shele\miniforge3\envs\ML_II\Lib\site-packages\kedro\ipython\__init__.py#61\61]8;;\
#                     INFO     Registered line magic '%load_node'                                      ]8;id=50409;file://c:\Users\shele\miniforge3\envs\ML_II\Lib\site-packages\kedro\ipython\__init__.py\__init__.py]8;;\:]8;id=808928;file://c:\Users\shele\miniforge3\envs\ML_II\Lib\site-packages\kedro\ipython\__init__.py#63\63]8;;\
#                     INFO     Resolved project path as: d:\UNIWERSYTET WARSZAWSKI\Machine Learning   ]8;id=532193;file://c:\Users\shele\miniforge3\envs\ML_II\Lib\site-packages\kedro\ipython\__init__.py\__init__.py]8;;\:]8;id=187599;file://c:\Users\shele\miniforge3\envs\ML_II\Lib\site-packages\kedro\ipython\__init__.py#178\178]8;;\
#                              in Finance\II\Projects\ML_travel_insurance.
#                              To set a different path, run '%reload_kedro <project_root>'
# [01/06/25 15:10:28] WARNING  c:\Users\shele\miniforge3\envs\ML_II\Lib\site-packages\kedro\framework ]8;id=845170;file://c:\Users\shele\miniforge3\envs\ML_II\Lib\warnings.py\warnings.py]8;;\:]8;id=5234;file://c:\Users\shele\miniforge3\envs\ML_II\Lib\warnings.py#112\112]8;;\
#                              \project\__init__.py:347: UserWarning: The
#                              'ml_travel_insurance.pipelines.data_processing' module does not expose
#                              a 'create_pipeline' function, so no pipelines defined therein will be
#                              returned by 'find_pipelines'.
#                                warnings.warn(
#                     WARNING  c:\Users\shele\miniforge3\envs\ML_II\Lib\site-packages\kedro\framework ]8;id=593185;file://c:\Users\shele\miniforge3\envs\ML_II\Lib\warnings.py\warnings.py]8;;\:]8;id=144728;file://c:\Users\shele\miniforge3\envs\ML_II\Lib\warnings.py#112\112]8;;\
#                              \project\__init__.py:347: UserWarning: The
#                              'ml_travel_insurance.pipelines.data_science' module does not expose a
#                              'create_pipeline' function, so no pipelines defined therein will be
#                              returned by 'find_pipelines'.
#                                warnings.warn(
#                     INFO     Kedro is sending anonymous usage data with the sole purpose of improving ]8;id=826589;file://c:\Users\shele\miniforge3\envs\ML_II\Lib\site-packages\kedro_telemetry\plugin.py\plugin.py]8;;\:]8;id=822316;file://c:\Users\shele\miniforge3\envs\ML_II\Lib\site-packages\kedro_telemetry\plugin.py#233\233]8;;\
#                              the product. No personal data or IP addresses are stored on our side. If
#                              you want to opt out, set the `KEDRO_DISABLE_TELEMETRY` or `DO_NOT_TRACK`
#                              environment variables, or create a `.telemetry` file in the current
#                              working directory with the contents `consent: false`. Read more at
#                              https://docs.kedro.org/en/stable/configuration/telemetry.html
# [01/06/25 15:10:29] INFO     Kedro project ML_travel_insurance                                      ]8;id=291168;file://c:\Users\shele\miniforge3\envs\ML_II\Lib\site-packages\kedro\ipython\__init__.py\__init__.py]8;;\:]8;id=118852;file://c:\Users\shele\miniforge3\envs\ML_II\Lib\site-packages\kedro\ipython\__init__.py#144\144]8;;\
#                     INFO     Defined global variable 'context', 'session', 'catalog' and            ]8;id=110771;file://c:\Users\shele\miniforge3\envs\ML_II\Lib\site-packages\kedro\ipython\__init__.py\__init__.py]8;;\:]8;id=878187;file://c:\Users\shele\miniforge3\envs\ML_II\Lib\site-packages\kedro\ipython\__init__.py#145\145]8;;\
#                              'pipelines'

# %%
catalog.list()
# Out:
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# [
#     'travel_insurance_raw',
#     'travel_insurance',
#     'TI_train',
#     'TI_test',
#     'TI_y_train',
#     'TI_y_test',
#     'parameters',
#     'params:model_options',
#     'params:model_options.test_size',
#     'params:model_options.random_state',
#     'params:travel_insurance',
#     'params:travel_insurance.target_col',
#     'params:travel_insurance.encoding',
#     'params:travel_insurance.encoding.one_hot_cols',
#     'params:travel_insurance.encoding.catboost',
#     'params:travel_insurance.encoding.catboost.cols'
# ]

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from category_encoders.cat_boost import CatBoostEncoder

# %% [markdown]
# ## EDA

# %%
X_train = catalog.load('TI_train')
X_test = catalog.load('TI_test')
y_train = catalog.load('TI_y_train')
y_test = catalog.load('TI_y_test')
# Out:
# [01/06/25 15:10:30] INFO     Loading data from TI_train (CSVDataset)...                         ]8;id=982824;file://c:\Users\shele\miniforge3\envs\ML_II\Lib\site-packages\kedro\io\data_catalog.py\data_catalog.py]8;;\:]8;id=22971;file://c:\Users\shele\miniforge3\envs\ML_II\Lib\site-packages\kedro\io\data_catalog.py#389\389]8;;\
#                     INFO     Loading data from TI_test (CSVDataset)...                          ]8;id=569967;file://c:\Users\shele\miniforge3\envs\ML_II\Lib\site-packages\kedro\io\data_catalog.py\data_catalog.py]8;;\:]8;id=953662;file://c:\Users\shele\miniforge3\envs\ML_II\Lib\site-packages\kedro\io\data_catalog.py#389\389]8;;\
#                     INFO     Loading data from TI_y_train (CSVDataset)...                       ]8;id=835591;file://c:\Users\shele\miniforge3\envs\ML_II\Lib\site-packages\kedro\io\data_catalog.py\data_catalog.py]8;;\:]8;id=805429;file://c:\Users\shele\miniforge3\envs\ML_II\Lib\site-packages\kedro\io\data_catalog.py#389\389]8;;\
#                     INFO     Loading data from TI_y_test (CSVDataset)...                        ]8;id=477220;file://c:\Users\shele\miniforge3\envs\ML_II\Lib\site-packages\kedro\io\data_catalog.py\data_catalog.py]8;;\:]8;id=325065;file://c:\Users\shele\miniforge3\envs\ML_II\Lib\site-packages\kedro\io\data_catalog.py#389\389]8;;\

# %%
X_train.head(10)
# Out:
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
#   agency    agency_type distribution_channel              product_name  \
# 0    EPX  Travel Agency               Online         Cancellation Plan
# 1    EPX  Travel Agency               Online         Cancellation Plan
# 2    EPX  Travel Agency               Online  2 way Comprehensive Plan
# 3    EPX  Travel Agency               Online  2 way Comprehensive Plan
# 4    C2B       Airlines               Online               Bronze Plan
# 5    RAB       Airlines               Online                Value Plan
# 6    EPX  Travel Agency               Online  2 way Comprehensive Plan
# 7    JZI       Airlines               Online                Basic Plan
# 8    KML  Travel Agency               Online                Value Plan
# 9    C2B       Airlines               Online               Bronze Plan
#
#    duration         destination  net_sales  commision gender  age
# 0        18         PHILIPPINES       13.0       0.00    NaN   36
# 1       101            THAILAND       20.0       0.00    NaN   30
# 2        25  KOREA, REPUBLIC OF       66.0       0.00    NaN   36
# 3        50               CHINA       44.0       0.00    NaN   36
# 4        21           SINGAPORE       33.5       8.38      F   22
# 5         6   BRUNEI DARUSSALAM       15.0       6.00      M   47
# 6       103            THAILAND       20.0       0.00    NaN   30
# 7         8             MYANMAR       18.0       6.30      F   32
# 8       128              FRANCE      109.0      41.42      M   48
# 9        17           SINGAPORE       20.0       5.00      F   21

# %% [markdown]
# ### Missing Values

# %%
print('Train size:', X_train.shape[0])
# Out:
# Train size: 50660

# %%
X_train.isna().sum()
# Out:
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# agency                      0
# agency_type                 0
# distribution_channel        0
# product_name                0
# duration                    0
# destination                 0
# net_sales                   0
# commision                   0
# gender                  36124
# age                         0
# dtype: int64

# %%
X_test.isna().sum()
# Out:
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# agency                     0
# agency_type                0
# distribution_channel       0
# product_name               0
# duration                   0
# destination                0
# net_sales                  0
# commision                  0
# gender                  8983
# age                        0
# dtype: int64

# %% [markdown]
# Only gender has missing values. We will create new category 'Missing' for them.

# %%
X_train.loc[X_train['gender'].isna(), 'gender'] = 'Missing'
X_train['gender'].head(10)
# Out:
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# 0    Missing
# 1    Missing
# 2    Missing
# 3    Missing
# 4          F
# 5          M
# 6    Missing
# 7          F
# 8          M
# 9          F
# Name: gender, dtype: object

# %% [markdown]
# ### Target Variable
#
# Target variable is very unbalanced, therefore for the train-test split, stratified version was used.

# %%
y_train = y_train == 'Yes'
y_test = y_test == 'Yes'

# %%
pd.DataFrame(
    {
        'train': y_train.value_counts(),
        'train_%': y_train.value_counts() / y_train.shape[0],
        'test': y_test.value_counts(),
        'test_%': y_test.value_counts() / y_test.shape[0],
    }
)
# Out:
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
#        train   train_%   test    test_%
# claim
# False  49918  0.985353  12481  0.985394
# True     742  0.014647    185  0.014606

# %% [markdown]
# ### Categorical Columns

# %% [markdown]
# - agency - use catboost encoding
# - agency_type - use one-hot encoding
# - distribution_channel - use one-hot encoding. Predominantly it is Online
# - product_name - use catboost encoding
# - gender - use one-hot encoding. Most of the gender is Missing
# - destination - use catboost encoding

# %% [markdown]
# #### Distributions

# %%
def get_pie_plot_data(col: str, perc: float = 0.05):
    initial_plot_data = pd.DataFrame({col: X_train[col]})
    plot_perc = initial_plot_data.value_counts() / initial_plot_data.shape[0]
    to_other = pd.DataFrame(
        {'other': plot_perc < perc, col: [ind[0] for ind in plot_perc.index.values]}
    )
    to_other.reset_index(drop=True, inplace=True)

    plot_data = pd.merge(initial_plot_data, to_other, left_on=col, right_on=col)
    plot_data.loc[plot_data['other'], col] = 'Other'

    return plot_data

# %%
fig, axs = plt.subplots(3, 2, figsize=(20, 20))
axs_flat = axs.flat


agency_plot_data = get_pie_plot_data('agency')
axs_flat[0].pie(
    agency_plot_data.value_counts(),
    labels=[ind[0] for ind in agency_plot_data.value_counts().index.values],
)

sns.countplot(data=X_train, x='agency_type', ax=axs_flat[1])
sns.countplot(data=X_train, x='distribution_channel', ax=axs_flat[2])

product_plot_data = get_pie_plot_data('product_name')
axs_flat[3].pie(
    product_plot_data.value_counts(),
    labels=[ind[0] for ind in product_plot_data.value_counts().index.values],
)

dest_plot_data = get_pie_plot_data('destination', perc=0.01)
axs_flat[4].pie(
    dest_plot_data.value_counts(),
    labels=[ind[0] for ind in dest_plot_data.value_counts().index.values],
)

sns.countplot(data=X_train, x='gender', ax=axs_flat[5])

plt.show()
# Out:
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# <Figure size 2000x2000 with 6 Axes>

# %% [markdown]
# #### Categorical Encoding

# %%
oh_cols = catalog.load('params:travel_insurance.encoding.one_hot_cols')

X_train_upd = pd.get_dummies(X_train, columns=oh_cols)
# Out:
# [01/06/25 15:10:32] INFO     Loading data from params:travel_insurance.encoding.one_hot_cols    ]8;id=45520;file://c:\Users\shele\miniforge3\envs\ML_II\Lib\site-packages\kedro\io\data_catalog.py\data_catalog.py]8;;\:]8;id=826459;file://c:\Users\shele\miniforge3\envs\ML_II\Lib\site-packages\kedro\io\data_catalog.py#389\389]8;;\
#                              (MemoryDataset)...

# %%
catboost_cols = catalog.load('params:travel_insurance.encoding.catboost.cols')

CBE_encoder = CatBoostEncoder(cols=catboost_cols)
X_train_upd = CBE_encoder.fit_transform(X_train_upd, y_train)
X_train_upd.head(10)
# Out:
#                     INFO     Loading data from params:travel_insurance.encoding.catboost.cols   ]8;id=635801;file://c:\Users\shele\miniforge3\envs\ML_II\Lib\site-packages\kedro\io\data_catalog.py\data_catalog.py]8;;\:]8;id=539519;file://c:\Users\shele\miniforge3\envs\ML_II\Lib\site-packages\kedro\io\data_catalog.py#389\389]8;;\
#                              (MemoryDataset)...
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
#      agency  product_name  duration  destination  net_sales  commision  age  \
# 0  0.014647      0.014647        18     0.014647       13.0       0.00   36
# 1  0.007323      0.007323       101     0.014647       20.0       0.00   30
# 2  0.004882      0.014647        25     0.014647       66.0       0.00   36
# 3  0.003662      0.007323        50     0.014647       44.0       0.00   36
# 4  0.014647      0.014647        21     0.014647       33.5       8.38   22
# 5  0.014647      0.014647         6     0.014647       15.0       6.00   47
# 6  0.002929      0.004882       103     0.007323       20.0       0.00   30
# 7  0.014647      0.014647         8     0.014647       18.0       6.30   32
# 8  0.014647      0.007323       128     0.014647      109.0      41.42   48
# 9  0.007323      0.007323        17     0.007323       20.0       5.00   21
#
#    agency_type_Airlines  agency_type_Travel Agency  \
# 0                 False                       True
# 1                 False                       True
# 2                 False                       True
# 3                 False                       True
# 4                  True                      False
# 5                  True                      False
# 6                 False                       True
# 7                  True                      False
# 8                 False                       True
# 9                  True                      False
#
#    distribution_channel_Offline  distribution_channel_Online  gender_F  \
# 0                         False                         True     False
# 1                         False                         True     False
# 2                         False                         True     False
# 3                         False                         True     False
# 4                         False                         True      True
# 5                         False                         True     False
# 6                         False                         True     False
# 7                         False                         True      True
# 8                         False                         True     False
# 9                         False                         True      True
#
#    gender_M  gender_Missing
# 0     False            True
# 1     False            True
# 2     False            True
# 3     False            True
# 4     False           False
# 5      True           False
# 6     False            True
# 7     False           False
# 8      True           False
# 9     False           False

# %% [markdown]
# ### Continuous Columns
#
# - duration - apply square root transformation
# - net_sales - apply cubic root transformation (sales can be negative)
# - commision - many contracts have no commision. Apply square transform
# - age - a lot of insured people are 36 years old somehow

# %%
X_train_upd['duration'] = np.where(
    X_train_upd['duration'] < 0, 0, X_train_upd['duration']
)
X_train_upd['duration_sqrt'] = np.sqrt(X_train_upd['duration'])

X_train_upd['net_sales_3'] = X_train_upd['net_sales'] ** (1 / 3)
X_train_upd['commision_sqrt'] = X_train_upd['commision'] ** 0.5

# %% [markdown]
# #### Distributions

# %%
fig, axs = plt.subplots(nrows=2, ncols=2, figsize=(15, 10))
axs_flat = axs.flat

sns.histplot(X_train_upd['duration_sqrt'], ax=axs_flat[0])
sns.histplot(X_train_upd['net_sales_3'], ax=axs_flat[1])
sns.histplot(X_train_upd['commision_sqrt'], ax=axs_flat[2])
sns.histplot(X_train_upd['age'], ax=axs_flat[3])

fig.tight_layout(pad=5)
plt.show()
# Out:
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# <Figure size 1500x1000 with 4 Axes>

# %%
X_train_upd.loc[X_train_upd['duration_sqrt'] > 18].describe()
# Out:
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
#             agency  product_name     duration  destination    net_sales  \
# count  1567.000000   1567.000000  1567.000000  1567.000000  1567.000000
# mean      0.061413      0.094998   403.962987     0.037553   222.978398
# std       0.018227      0.039621   350.023883     0.012370    92.889119
# min       0.000130      0.000163   325.000000     0.000118  -389.000000
# 25%       0.064401      0.096444   365.000000     0.041587   204.600000
# 50%       0.066266      0.108744   368.000000     0.042355   216.000000
# 75%       0.067524      0.113102   379.000000     0.043724   256.200000
# max       0.251831      0.507323  4881.000000     0.049194   666.000000
#
#          commision          age  duration_sqrt  net_sales_3  commision_sqrt
# count  1567.000000  1567.000000    1567.000000  1549.000000     1567.000000
# mean     69.470466    40.898532      19.698736     5.943662        7.857599
# std      43.069700    12.591957       3.991611     1.140448        2.780923
# min       0.000000     5.000000      18.027756     0.000000        0.000000
# 25%      54.000000    31.000000      19.104973     5.892531        7.348469
# 50%      54.000000    38.000000      19.183326     6.000000        7.348469
# 75%      71.850000    49.000000      19.467922     6.351257        8.476438
# max     262.760000    84.000000      69.864154     8.732892       16.209874

# %%
X_train_upd.loc[X_train_upd['duration_sqrt'] < 18].describe()
# Out:
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
#              agency  product_name      duration   destination     net_sales  \
# count  49091.000000  49091.000000  49091.000000  49091.000000  49091.000000
# mean       0.012969      0.011877     37.655028      0.013823     34.734120
# std        0.019246      0.016836     44.730494      0.015639     32.781153
# min        0.000049      0.000055      0.000000      0.000023   -357.500000
# 25%        0.005399      0.002535      9.000000      0.004014     18.000000
# 50%        0.005846      0.006103     21.000000      0.007078     26.000000
# 75%        0.007806      0.011353     48.000000      0.014425     44.000000
# max        0.253662      0.202929    323.000000      0.507323    810.000000
#
#           commision           age  duration_sqrt   net_sales_3  commision_sqrt
# count  49091.000000  49091.000000   49091.000000  48563.000000    49091.000000
# mean       7.888492     39.975413       5.328484      3.041723        1.667698
# std       15.158313     14.105948       3.043432      0.933571        2.259951
# min        0.000000      0.000000       0.000000      0.000000        0.000000
# 25%        0.000000     35.000000       3.000000      2.620741        0.000000
# 50%        0.000000     36.000000       4.582576      2.962496        0.000000
# 75%        9.750000     43.000000       6.928203      3.552937        3.122499
# max      283.500000    118.000000      17.972201      9.321698       16.837458

# %% [markdown]
# It seems, spike in duration distribution is caused by some products with high net sales (on average), and destination seems to differ. Let's check it on unchanged dataset.

# %%
X_train.loc[X_train['duration'] > 18**2, 'agency'].value_counts()
# Out:
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# agency
# C2B    1267
# LWC     195
# TTW      77
# SSI      13
# EPX       7
# CWT       6
# ART       1
# JZI       1
# Name: count, dtype: int64

# %%
X_train.loc[
    X_train['duration'] > 18**2,
    ['agency', 'product_name', 'destination', 'agency_type'],
].value_counts()
# Out:
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# agency  product_name                          destination         agency_type
# C2B     Annual Silver Plan                    SINGAPORE           Airlines         1110
#         Annual Gold Plan                      SINGAPORE           Airlines          153
# LWC     Annual Travel Protect Gold            UNITED STATES       Travel Agency      63
# TTW     Individual Comprehensive Plan         SINGAPORE           Travel Agency      44
# LWC     Annual Travel Protect Silver          UNITED STATES       Travel Agency      40
#         Annual Travel Protect Platinum        UNITED STATES       Travel Agency      38
#         Annual Travel Protect Silver          CHINA               Travel Agency      26
#         Annual Travel Protect Gold            CHINA               Travel Agency      19
# SSI     Ticket Protector                      SINGAPORE           Airlines           13
# TTW     Individual Comprehensive Plan         AUSTRALIA           Travel Agency      12
#         Spouse or Parents Comprehensive Plan  SINGAPORE           Travel Agency       9
#         Child Comprehensive Plan              SINGAPORE           Travel Agency       6
# LWC     Annual Travel Protect Silver          INDONESIA           Travel Agency       5
# CWT     Rental Vehicle Excess Insurance       AUSTRALIA           Travel Agency       5
# C2B     Bronze Plan                           SINGAPORE           Airlines            4
# LWC     Annual Travel Protect Gold            INDONESIA           Travel Agency       2
# EPX     Cancellation Plan                     PERU                Travel Agency       2
# LWC     Annual Travel Protect Platinum        CHINA               Travel Agency       2
# TTW     Spouse or Parents Comprehensive Plan  AUSTRALIA           Travel Agency       2
# EPX     Cancellation Plan                     UNITED STATES       Travel Agency       1
# TTW     Individual Comprehensive Plan         HONG KONG           Travel Agency       1
#         Spouse or Parents Comprehensive Plan  MALAYSIA            Travel Agency       1
#                                               HONG KONG           Travel Agency       1
#         Individual Comprehensive Plan         THAILAND            Travel Agency       1
# CWT     Rental Vehicle Excess Insurance       MALAYSIA            Travel Agency       1
# JZI     Basic Plan                            KOREA, REPUBLIC OF  Airlines            1
# EPX     2 way Comprehensive Plan              INDIA               Travel Agency       1
#                                               THAILAND            Travel Agency       1
#         Cancellation Plan                     INDIA               Travel Agency       1
#                                               PHILIPPINES         Travel Agency       1
# ART     24 Protect                            PHILIPPINES         Airlines            1
# Name: count, dtype: int64

# %% [markdown]
# Predominantly it is one agency C2B, dealing with Airlines and Singapore destination.

# %% [markdown]
# ### Correlations
#
# Interestingly, missing gender has high correlation with agency_type=Travel Agency, while for Airlines there is a positive correlation with genders. Maybe, one is not obliged to fill in their gender?
#
# Also, there is some correlation between destination and agency/product_name. It seems that some products are only relevant for Travel Agencies, while others are only for Airlines, which is expected, I suppose.
#
# Commision is correlated with net sales.

# %%
plt.figure(figsize=(15, 15))
corr_ax = sns.heatmap(X_train_upd.corr())
# Out:
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# <Figure size 1500x1500 with 2 Axes>
