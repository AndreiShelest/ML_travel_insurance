# %%
# %load_ext kedro.ipython
# %reload_kedro
# Out:
# The kedro.ipython extension is already loaded. To reload it, use:
#   %reload_ext kedro.ipython
# [01/05/25 11:32:18] INFO     Resolved project path as: D:\UNIWERSYTET WARSZAWSKI\Machine Learning   ]8;id=545078;file://c:\Users\shele\miniforge3\envs\ML_II\Lib\site-packages\kedro\ipython\__init__.py\__init__.py]8;;\:]8;id=705025;file://c:\Users\shele\miniforge3\envs\ML_II\Lib\site-packages\kedro\ipython\__init__.py#178\178]8;;\
#                              in Finance\II\Projects\ML_travel_insurance.
#                              To set a different path, run '%reload_kedro <project_root>'
#                     WARNING  c:\Users\shele\miniforge3\envs\ML_II\Lib\site-packages\kedro\framework ]8;id=59417;file://c:\Users\shele\miniforge3\envs\ML_II\Lib\warnings.py\warnings.py]8;;\:]8;id=145433;file://c:\Users\shele\miniforge3\envs\ML_II\Lib\warnings.py#112\112]8;;\
#                              \project\__init__.py:347: UserWarning: The
#                              'ml_travel_insurance.pipelines.data_processing' module does not expose
#                              a 'create_pipeline' function, so no pipelines defined therein will be
#                              returned by 'find_pipelines'.
#                                warnings.warn(
#                     WARNING  c:\Users\shele\miniforge3\envs\ML_II\Lib\site-packages\kedro\framework ]8;id=672695;file://c:\Users\shele\miniforge3\envs\ML_II\Lib\warnings.py\warnings.py]8;;\:]8;id=654904;file://c:\Users\shele\miniforge3\envs\ML_II\Lib\warnings.py#112\112]8;;\
#                              \project\__init__.py:347: UserWarning: The
#                              'ml_travel_insurance.pipelines.data_science' module does not expose a
#                              'create_pipeline' function, so no pipelines defined therein will be
#                              returned by 'find_pipelines'.
#                                warnings.warn(
#                     INFO     Kedro is sending anonymous usage data with the sole purpose of improving ]8;id=855837;file://c:\Users\shele\miniforge3\envs\ML_II\Lib\site-packages\kedro_telemetry\plugin.py\plugin.py]8;;\:]8;id=317750;file://c:\Users\shele\miniforge3\envs\ML_II\Lib\site-packages\kedro_telemetry\plugin.py#233\233]8;;\
#                              the product. No personal data or IP addresses are stored on our side. If
#                              you want to opt out, set the `KEDRO_DISABLE_TELEMETRY` or `DO_NOT_TRACK`
#                              environment variables, or create a `.telemetry` file in the current
#                              working directory with the contents `consent: false`. Read more at
#                              https://docs.kedro.org/en/stable/configuration/telemetry.html
# [01/05/25 11:32:19] INFO     Kedro project ML_travel_insurance                                      ]8;id=350349;file://c:\Users\shele\miniforge3\envs\ML_II\Lib\site-packages\kedro\ipython\__init__.py\__init__.py]8;;\:]8;id=498726;file://c:\Users\shele\miniforge3\envs\ML_II\Lib\site-packages\kedro\ipython\__init__.py#144\144]8;;\
#                     INFO     Defined global variable 'context', 'session', 'catalog' and            ]8;id=732250;file://c:\Users\shele\miniforge3\envs\ML_II\Lib\site-packages\kedro\ipython\__init__.py\__init__.py]8;;\:]8;id=885947;file://c:\Users\shele\miniforge3\envs\ML_II\Lib\site-packages\kedro\ipython\__init__.py#145\145]8;;\
#                              'pipelines'

# %%
catalog.list()
# Out:
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# [
#     'travel_insurance',
#     'TI_train_raw',
#     'TI_test_raw',
#     'TI_y_train_raw',
#     'TI_y_test_raw',
#     'parameters',
#     'params:model_options',
#     'params:model_options.test_size',
#     'params:model_options.random_state',
#     'params:travel_insurance',
#     'params:travel_insurance.target_col'
# ]

# %%
import numpy as np
import seaborn as sns

import matplotlib.pyplot as plt

# %% [markdown]
# ### EDA

# %% [markdown]
# Target label is imbalanced, hence we are using stratified train-test split.

# %%
X_train = catalog.load('TI_train_raw')
X_test = catalog.load('TI_test_raw')
y_train = catalog.load('TI_y_train_raw')
# Out:
#                     INFO     Loading data from TI_train_raw (CSVDataset)...                     ]8;id=864328;file://c:\Users\shele\miniforge3\envs\ML_II\Lib\site-packages\kedro\io\data_catalog.py\data_catalog.py]8;;\:]8;id=685212;file://c:\Users\shele\miniforge3\envs\ML_II\Lib\site-packages\kedro\io\data_catalog.py#389\389]8;;\
#                     INFO     Loading data from TI_test_raw (CSVDataset)...                      ]8;id=47539;file://c:\Users\shele\miniforge3\envs\ML_II\Lib\site-packages\kedro\io\data_catalog.py\data_catalog.py]8;;\:]8;id=388316;file://c:\Users\shele\miniforge3\envs\ML_II\Lib\site-packages\kedro\io\data_catalog.py#389\389]8;;\
#                     INFO     Loading data from TI_y_train_raw (CSVDataset)...                   ]8;id=230354;file://c:\Users\shele\miniforge3\envs\ML_II\Lib\site-packages\kedro\io\data_catalog.py\data_catalog.py]8;;\:]8;id=132350;file://c:\Users\shele\miniforge3\envs\ML_II\Lib\site-packages\kedro\io\data_catalog.py#389\389]8;;\

# %%
X_train.head(10)
# Out:
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
#   Agency    Agency Type Distribution Channel              Product Name  \
# 0    EPX  Travel Agency               Online         Cancellation Plan
# 1    EPX  Travel Agency               Online         Cancellation Plan
# 2    EPX  Travel Agency               Online  2 way Comprehensive Plan
# 3    EPX  Travel Agency               Online  2 way Comprehensive Plan
# 4    C2B       Airlines               Online               Bronze Plan
# 5    RAB       Airlines               Online                Value Plan
# 6    EPX  Travel Agency               Online  2 way Comprehensive Plan
# 7    JZI       Airlines               Online                Basic Plan
# 8    KML  Travel Agency               Online                Value Plan
# 9    C2B       Airlines               Online               Bronze Plan
#
#    Duration         Destination  Net Sales  Commision (in value) Gender  Age
# 0        18         PHILIPPINES       13.0                  0.00    NaN   36
# 1       101            THAILAND       20.0                  0.00    NaN   30
# 2        25  KOREA, REPUBLIC OF       66.0                  0.00    NaN   36
# 3        50               CHINA       44.0                  0.00    NaN   36
# 4        21           SINGAPORE       33.5                  8.38      F   22
# 5         6   BRUNEI DARUSSALAM       15.0                  6.00      M   47
# 6       103            THAILAND       20.0                  0.00    NaN   30
# 7         8             MYANMAR       18.0                  6.30      F   32
# 8       128              FRANCE      109.0                 41.42      M   48
# 9        17           SINGAPORE       20.0                  5.00      F   21

# %% [markdown]
# #### Agency

# %%
agency_names = np.unique(np.concatenate([X_train['Agency'], X_test['Agency']]))
agency_names
# Out:
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# array(['ADM', 'ART', 'C2B', 'CBH', 'CCR', 'CSR', 'CWT', 'EPX', 'JWT',
#        'JZI', 'KML', 'LWC', 'RAB', 'SSI', 'TST', 'TTW'], dtype=object)

# %% [markdown]
# #### Agency Type

# %%
agency_types = np.unique(
    np.concatenate([X_train['Agency Type'], X_test['Agency Type']])
)
agency_types
# Out:
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# array(['Airlines', 'Travel Agency'], dtype=object)

# %% [markdown]
# #### Distribution Channel
